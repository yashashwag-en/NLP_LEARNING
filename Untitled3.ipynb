# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 16.9 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import nltk

# %%
sentences = {
    "I am learning natural language processing",
    "Natural language processing is fun",
    "I love learning natural language processing",
    "Deep learning uses nureal networks"
}

# %%
#tokenize:
tokenized_sentences = [word_tokenize(s.lower()) for s in sentences]

# %%
print(tokenized_sentences)
# Out:
# [['i', 'am', 'learning', 'natural', 'language', 'processing'], ['i', 'love', 'learning', 'natural', 'language', 'processing'], ['natural', 'language', 'processing', 'is', 'fun'], ['deep', 'learning', 'uses', 'nureal', 'networks']]

# %%
model = Word2Vec(
    sentences = tokenized_sentences,
    vector_size = 100,
    window = 3,
    min_count = 1
)

# %%
print("Similarity b/w natural and deep")
print(model.wv.similarity("natural","deep"))
# Out:
# Similarity b/w natural and deep
# 0.19912723

# %%
print("Most similar words to learning")
print(model.wv.most_similar("learning"))

# %%
import gensim.downloader as api
print("Loading pretainer model:")
model = api.load("glove-wiki-gigaword-100")
